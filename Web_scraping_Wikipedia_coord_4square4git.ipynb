# %% [markdown]
# ## Importing BeautifulSoup, requests and pandas libraries

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page
import pandas as pd

# %% [markdown]
# ## Defining data source webpage from wikipedia

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %% [markdown]
# ## Using requests to get web page text and beautifulsoup to format it to html

# %%
data  = requests.get(url).text 
soup = BeautifulSoup(data,'html5lib')

# %% [markdown]
# ## Extracting tables from the soup

# %%
table_contents=[]  # Blank list to contain table data
table=soup.find('table')

# %% [markdown]
# ## Extracting data from table and creating a list with the data

# %%
for row in table.findAll('td'):            ## iterating between all normal table cells - tag 'td'
    cell = {}                              ## creating blank dictionary which will contain each row data
    if row.span.text == 'Not assigned':    ## ignoring cells that contain 'Not assigned'
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]              #extracting 3 characters of postal code from row
        cell['Borough'] = (row.span.text).split('(')[0]  #extracting text before first open bracket
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')').replace('/',',')).replace(')', ' ')).strip(' ')) 
        ## line above extracts element after first parenthesis and remove closing bracket then replace / and , ) for blanks
        table_contents.append(cell)  #adding the dictionary to table contents

# %% [markdown]
# ## Transforming table_contents list into pandas Dataframe

# %%
df=pd.DataFrame(table_contents)  ##converting list to dataframe
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                     'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                     'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                     'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})

## line above clean few cells that were not extracted right

#df.drop_duplicates(subset = 'Neighborhood', keep='first', inplace= True) # dropping duplicates
df
# Out:
#     PostalCode                Borough  \
# 0          M3A             North York
# 1          M4A             North York
# 2          M5A       Downtown Toronto
# 3          M6A             North York
# 4          M7A           Queen's Park
# ..         ...                    ...
# 98         M8X              Etobicoke
# 99         M4Y       Downtown Toronto
# 100        M7Y  East Toronto Business
# 101        M8Y              Etobicoke
# 102        M8Z              Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park , Harbourfront
# 3                    Lawrence Manor , Lawrence Heights
# 4                        Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway , Montgomery Road , Old Mill North
# 99                                Church and Wellesley
# 100                                     Enclave of M4L
# 101  Old Mill South , King's Mill Park , Sunnylea ,...
# 102  Mimico NW , The Queensway West , South of Bloo...
#
# [103 rows x 3 columns]

# %% [markdown]
# ## Number of rows in the dataframe

# %%
print('The number of rows in the dataframe is: {}'.format(df.shape[0]))
# Out:
# The number of rows in the dataframe is: 103

# %% [markdown]
# ## Installing geocoder

# %%
! pip install geocoder
# Out:
# Requirement already satisfied: geocoder in d:\programming\anaconda\lib\site-packages (1.38.1)
# Requirement already satisfied: ratelim in d:\programming\anaconda\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: click in d:\programming\anaconda\lib\site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: six in d:\programming\anaconda\lib\site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: future in d:\programming\anaconda\lib\site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: requests in d:\programming\anaconda\lib\site-packages (from geocoder) (2.24.0)
# Requirement already satisfied: decorator in d:\programming\anaconda\lib\site-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: idna<3,>=2.5 in d:\programming\anaconda\lib\site-packages (from requests->geocoder) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\programming\anaconda\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\programming\anaconda\lib\site-packages (from requests->geocoder) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programming\anaconda\lib\site-packages (from requests->geocoder) (2020.12.5)

# %% [markdown]
# ## Obtaining Coordinates of postal codes -- Geocoder did not work -- never exiting loop

# %%
# import geocoder # import geocoder

# initialize your variable to None
# lat_lng_coords = None

# loop until you get the coordinates
# while(lat_lng_coords is None):
#  g = geocoder.google('{}, Toronto, Ontario'.format('M5G'))
#  lat_lng_coords = g.latlng

# latitude = lat_lng_coords[0]
# longitude = lat_lng_coords[1]

# %% [markdown]
# ## Importing csv with coordinates

# %%
file = 'Geospatial_Coordinates.csv'
Geo_coord = pd.read_csv(file)
Geo_coord = Geo_coord.rename(columns={'Postal Code': 'PostalCode'})
Geo_coord
# Out:
#     PostalCode   Latitude  Longitude
# 0          M1B  43.806686 -79.194353
# 1          M1C  43.784535 -79.160497
# 2          M1E  43.763573 -79.188711
# 3          M1G  43.770992 -79.216917
# 4          M1H  43.773136 -79.239476
# ..         ...        ...        ...
# 98         M9N  43.706876 -79.518188
# 99         M9P  43.696319 -79.532242
# 100        M9R  43.688905 -79.554724
# 101        M9V  43.739416 -79.588437
# 102        M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
df = pd.merge(df, Geo_coord, how='left')
df
# Out:
#     PostalCode                Borough  \
# 0          M3A             North York
# 1          M4A             North York
# 2          M5A       Downtown Toronto
# 3          M6A             North York
# 4          M7A           Queen's Park
# ..         ...                    ...
# 98         M8X              Etobicoke
# 99         M4Y       Downtown Toronto
# 100        M7Y  East Toronto Business
# 101        M8Y              Etobicoke
# 102        M8Z              Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                           Regent Park , Harbourfront  43.654260 -79.360636
# 3                    Lawrence Manor , Lawrence Heights  43.718518 -79.464763
# 4                        Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98     The Kingsway , Montgomery Road , Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100                                     Enclave of M4L  43.662744 -79.321558
# 101  Old Mill South , King's Mill Park , Sunnylea ,...  43.636258 -79.498509
# 102  Mimico NW , The Queensway West , South of Bloo...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# ## Foursquare Credentials

# %%
CLIENT_ID = '@@' # your Foursquare ID
CLIENT_SECRET = '@@' # your Foursquare Secret
ACCESS_TOKEN = '@@' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: @@
# CLIENT_SECRET:@@

# %% [markdown]
# ## Explore Etobicoke Borough -- 11 entries

# %%
Nhoods = df[df['Borough'] == 'Etobicoke']
Nhoods
# Out:
#     PostalCode    Borough                                       Neighborhood  \
# 5          M9A  Etobicoke                                   Islington Avenue
# 11         M9B  Etobicoke  West Deane Park , Princess Gardens , Martin Gr...
# 17         M9C  Etobicoke  Eringate , Bloordale Gardens , Old Burnhamthor...
# 70         M9P  Etobicoke                                          Westmount
# 77         M9R  Etobicoke  Kingsview Village , St. Phillips , Martin Grov...
# 88         M8V  Etobicoke     New Toronto , Mimico South , Humber Bay Shores
# 89         M9V  Etobicoke  South Steeles , Silverstone , Humbergate , Jam...
# 93         M8W  Etobicoke                            Alderwood , Long Branch
# 98         M8X  Etobicoke    The Kingsway , Montgomery Road , Old Mill North
# 101        M8Y  Etobicoke  Old Mill South , King's Mill Park , Sunnylea ,...
# 102        M8Z  Etobicoke  Mimico NW , The Queensway West , South of Bloo...
#
#       Latitude  Longitude
# 5    43.667856 -79.532242
# 11   43.650943 -79.554724
# 17   43.643515 -79.577201
# 70   43.696319 -79.532242
# 77   43.688905 -79.554724
# 88   43.605647 -79.501321
# 89   43.739416 -79.588437
# 93   43.602414 -79.543484
# 98   43.653654 -79.506944
# 101  43.636258 -79.498509
# 102  43.628841 -79.520999

# %% [markdown]
# # Map the 10 most popular venues on each  of the Etobicoke Neighborhoods

# %%
LIMIT = 10

# %% [markdown]
# ## Loop: Define url get json file and convert to dataframe

# %%
## Define blank dataframe to contain all venues
col = ['name', 'categories', 'address', 'lat', 'lng', 'labeledLatLngs',
       'distance', 'postalCode', 'cc', 'city', 'state', 'country',
       'formattedAddress', 'crossStreet', 'id']
rdf = pd.DataFrame(columns = col)
rdf
# Out:
# Empty DataFrame
# Columns: [name, categories, address, lat, lng, labeledLatLngs, distance, postalCode, cc, city, state, country, formattedAddress, crossStreet, id]
# Index: []

# %%
# function that extracts the category of the venue

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# Loop starts selecting coordinates for each Borough
for i,rows in Nhoods.iterrows():
    lat = rows['Latitude']
    lon = rows['Longitude']
    
#getting 10 most popular venues on each Neighborhood of Etobicoke
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, lon, VERSION, LIMIT)
    results = requests.get(url).json() ## get data from foursquare
    items = results['response']['groups'][0]['items'] ## filter useful data
    items[0] 

## Process json file to dataframe
# tranforming json file into a pandas dataframe library
    from pandas.io.json import json_normalize
    dataframe = json_normalize(items) # flatten JSON

#filter columns
    filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
    dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
    dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
    dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]
    #print(dataframe_filtered.head())

#Store all results in the rdf dataframe
    rdf = rdf.append(dataframe_filtered)
rdf
# Out:
# D:\Programming\Anaconda\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                            name     categories                  address  \
# 0              South St. Burger   Burger Joint       1020 Islington Ave
# 1                    Wingporium    Wings Joint       1000 Islington Ave
# 2   Power Yoga Canada Etobicoke    Yoga Studio       1092 Islington Ave
# 3       Fat Bastard Burrito Co.  Burrito Place       1180 The Queensway
# 4           Dimpflmeier Factory         Bakery           20 Advance Rd.
# ..                          ...            ...                      ...
# 5                     Starbucks    Coffee Shop        829 The Queensway
# 6              Cineplex Cinemas  Movie Theater       1025 The Queensway
# 7                  Burrito Boyz  Burrito Place       1197 The Queensway
# 8            The Pie Commission     Restaurant        935 The Queensway
# 9           Great Lakes Brewery        Brewery  33 Queen Elizabeth Blvd
#
#           lat        lng                                     labeledLatLngs  \
# 0   43.631314 -79.518408  [{'label': 'display', 'lat': 43.63131374571208...
# 1   43.630275 -79.518169  [{'label': 'display', 'lat': 43.63027535508102...
# 2   43.636592 -79.520312  [{'label': 'display', 'lat': 43.63659220688171...
# 3   43.622099 -79.521880  [{'label': 'display', 'lat': 43.62209851449942...
# 4   43.633773 -79.529895  [{'label': 'display', 'lat': 43.63377341289872...
# ..        ...        ...                                                ...
# 5   43.624654 -79.508217  [{'label': 'display', 'lat': 43.624654, 'lng':...
# 6   43.621251 -79.515346  [{'label': 'display', 'lat': 43.62125133114305...
# 7   43.621791 -79.522601  [{'label': 'display', 'lat': 43.62179051874228...
# 8   43.623548 -79.512265  [{'label': 'display', 'lat': 43.62354819663253...
# 9   43.622796 -79.504677  [{'label': 'display', 'lat': 43.62279645548608...
#
#    distance postalCode  cc       city state country  \
# 0       345    M8Z 6A4  CA  Etobicoke    ON  Canada
# 1       278    M8Z 4P8  CA    Toronto    ON  Canada
# 2       864        NaN  CA  Etobicoke    ON  Canada
# 3       753        NaN  CA  Etobicoke    ON  Canada
# 4       902    M8Z 2S6  CA    Toronto    ON  Canada
# ..      ...        ...  ..        ...   ...     ...
# 5      1130    M8Z 1N6  CA    Toronto    ON  Canada
# 6       959    M8Z 6C7  CA    Toronto    ON  Canada
# 7       795    M8Z 1S8  CA    Toronto    ON  Canada
# 8       917    M8Z 1P3  CA  Etobicoke    ON  Canada
# 9      1477    M8Z 1L8  CA    Toronto    ON  Canada
#
#                                      formattedAddress  \
# 0   [1020 Islington Ave, Etobicoke ON M8Z 6A4, Can...
# 1   [1000 Islington Ave (at Titan Rd), Toronto ON ...
# 2          [1092 Islington Ave, Etobicoke ON, Canada]
# 3          [1180 The Queensway, Etobicoke ON, Canada]
# 4   [20 Advance Rd. (btwn Kipling Ave & Islington ...
# ..                                                ...
# 5   [829 The Queensway (Taymall Avenue), Toronto O...
# 6   [1025 The Queensway (at Islington Ave.), Toron...
# 7   [1197 The Queensway (at Kipling), Toronto ON M...
# 8   [935 The Queensway (at Canmotor Ave.), Etobico...
# 9   [33 Queen Elizabeth Blvd (at Royal York Rd), T...
#
#                          crossStreet                        id neighborhood
# 0                                NaN  4bc9f9b6b6c49c7469688f91          NaN
# 1                        at Titan Rd  4b5fcadff964a520eecc29e3          NaN
# 2                                NaN  4e38175dd4c0dc7ad2ec326a          NaN
# 3                                NaN  4b6b2764f964a52034f62be3          NaN
# 4   btwn Kipling Ave & Islington Ave  4b62064df964a5202e312ae3          NaN
# ..                               ...                       ...          ...
# 5                     Taymall Avenue  55fd4770498e7a8fbc9082fe          NaN
# 6                  at Islington Ave.  4b0073a7f964a520643e22e3          NaN
# 7                         at Kipling  4d322a6d8c42a1cd1c10e65d          NaN
# 8                   at Canmotor Ave.  520546a311d2e15052dc4061          NaN
# 9                   at Royal York Rd  4aeb1c5ff964a5207bbe21e3          NaN
#
# [120 rows x 16 columns]

# %% [markdown]
# ## Installing folium

# %%
! pip install folium==0.5.0
# Out:
# Requirement already satisfied: folium==0.5.0 in d:\programming\anaconda\lib\site-packages (0.5.0)
# Requirement already satisfied: jinja2 in d:\programming\anaconda\lib\site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: branca in d:\programming\anaconda\lib\site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: six in d:\programming\anaconda\lib\site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: requests in d:\programming\anaconda\lib\site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\programming\anaconda\lib\site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programming\anaconda\lib\site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\programming\anaconda\lib\site-packages (from requests->folium==0.5.0) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\programming\anaconda\lib\site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in d:\programming\anaconda\lib\site-packages (from requests->folium==0.5.0) (2.9)

# %% [markdown]
# ## Visualizing in a map

# %%
import folium # plotting library


venues_map = folium.Map(location=[43.667856, -79.532242], zoom_start=11) # generate map centred around Bourough

# Loop starts selecting coordinates for each Borough
for lat, long, label in zip(Nhoods.Latitude, Nhoods.Longitude, Nhoods.Neighborhood):
                            
#i,rows in Nhoods.iterrows():
#    lat = rows['Latitude']
#    lon = rows['Longitude']
#    Nhd = rows['Neighborhood']
    
# add Neighborhood center as a red circle mark
    folium.CircleMarker(
        [lat, long],
        radius=10,
        popup=label.partition(',')[0],
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
        ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, lab in zip(rdf.lat, rdf.lng, rdf.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup='popular',
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_61dac8c8f995441fa30df5f111ca21f3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_61dac8c8f995441fa30df5f111ca21f3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_61dac8c8f995441fa30df5f111ca21f3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_61dac8c8f995441fa30df5f111ca21f3%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.667856%2C-79.532242%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# # Observations:
# #### Most of the popular venues of Mimico NW and Old Mill South neighborhoods are located along the Queensway road
# #### Most of the popular venues of The Kinsway neighborhood are located near the intersection of Bloor Street West and Royal York Road
# ### Most of the popular venues on Etobicoke Borough are concentrated in the South.
#
# #### *Check readme if map is not displayed*
